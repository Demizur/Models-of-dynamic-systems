# %%
import matplotlib.pyplot as plt
import numpy as np

a = 1
b = -0.5
x0 = 0
N = 100
M = 10
n_val = []
x_val = []

n_val.append(0)
x_val.append(x0)

x = x0

for i in range(1, N+1):
    x = a*x + b
    n_val.append(i)
    x_val.append(x)
# Вывод графиков

fig, ax = plt.subplots()
plt.title('График движения линейной системы')
ax.plot(n_val, x_val, label='f(x)')
ax.grid(which = 'both')
plt.tick_params(axis='both', which='major')
plt.xlabel('n')
plt.ylabel('x')

plt.show()

print("Числовые значения последних "+str(M)+" точек:\n")
for i in range(0, M):
    print(str(n_val[-(M-i)])+"\t"+str(round(x_val[-(M-i)], 4)))
    
#-------------------------------------ЛАМЕРЕЙ------------------------------------------
xmin = -2
xmax = 2
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4) 

ylist = a*xlist + b

def ff(x):
        return a*x + b

def fl(x):
        return x
x=0.25
y=0
Y=[]
X=[]
for i in range(1,N,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y

x1=xlist;
y1=[ff(x) for x in x1]
y2=[fl(x) for x in x1]

fig, ax = plt.subplots()
plt.title('Лестица Ламерея линейной системы')
ax.plot(X,Y,'r')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,y1,'b',label='f(x) = a*x + b')
plt.plot(x1,y2,'g',label='f(x) = x')
plt.grid(True)
#ax.set_xlim([-10,0])
#ax.set_ylim([-10,0])
plt.legend()
plt.show()
#-------------------------------------Функция f(2)(x)----------------------------------------

def ff2(x):
        return a*a*x + b*(a+1)

x1=xlist;
y1=[ff2(x) for x in x1]

fig, ax = plt.subplots()
plt.title('График функции второй итерации линейной системы')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,y1,'b')
plt.grid(True)
#ax.set_xlim([-10,0])
#ax.set_ylim([-10,0])
plt.show()
# Out:
# Числовые значения последних 10 точек:
#
# 91	-45.5
# 92	-46.0
# 93	-46.5
# 94	-47.0
# 95	-47.5
# 96	-48.0
# 97	-48.5
# 98	-49.0
# 99	-49.5
# 100	-50.0

# %%
a = 1
b = 0.5
c= 0.5
d=-1
x0 = 0
N = 20
M = 10
n_val = []
x_val = []

n_val.append(0)
x_val.append(x0)

x = x0

for i in range(1, N+1):
    x = (a*x + b)/(c*x+d)
    n_val.append(i)
    x_val.append(x)
# Вывод графиков

fig, ax = plt.subplots()
plt.title('График движения дробно-линейной системы')
ax.plot(n_val, x_val, label='f(x)')
ax.grid(which = 'both')
plt.tick_params(axis='both', which='major')
plt.xlabel('n')
plt.ylabel('x')

plt.show()


    
#-------------------------------------ЛАМЕРЕЙ------------------------------------------
import decimal
import numpy as np

xmin = -5
xmax = 10
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4) # Построение графика с асимптотами

ylist = (a * xlist + b)/(c * xlist + d)

def ff(x):
        return (a*x + b)/(c*x+d)

def fl(x):
        return x
x=x0
y=0
Y=[]
X=[]
for i in range(1,N,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y

y1=[ff(x) for x in xlist]
y2=[fl(x) for x in xlist]

fig, ax = plt.subplots()
plt.title('Лестица Ламерея дробно-линейной системы')
ax.plot(X,Y,'r')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(xlist,ylist,'b',label='f(x) = (a*x + b)/(c*x+d)')
plt.plot(xlist,y2,'g',label='f(x) = x')
plt.grid(True)
ax.set_xlim([-5,7])
ax.set_ylim([-5,7])
plt.legend()
plt.show()
#-------------------------------------Функция f(2)(x)----------------------------------------

def ff2(x):
        return (1.75*x - 0.5)/1.25
    
x1=xlist;
y1=[ff2(x) for x in x1]

fig, ax = plt.subplots()
plt.title('График функции второй итерации дробно-линейной системы')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(xlist,y1,'b')
plt.grid(True)
#ax.set_xlim([-10,0])
#ax.set_ylim([-10,0])
plt.show()
# Out:
# <ipython-input-2-80d9cbaae7bf>:44: RuntimeWarning: divide by zero encountered in true_divide
#   ylist = (a * xlist + b)/(c * xlist + d)
# <ipython-input-2-80d9cbaae7bf>:47: RuntimeWarning: divide by zero encountered in double_scalars
#   return (a*x + b)/(c*x+d)

# %%
import matplotlib.pyplot as plt
import numpy as np

a = 1.5
x0 = 0.5
N = 100
M = 10
n_val = []
x_val = []

n_val.append(0)
x_val.append(x0)

x = x0

for i in range(1, N+1):
    x = a*x*(1-x) 
    n_val.append(i)
    x_val.append(x)
# Вывод графиков

fig, ax = plt.subplots()
plt.title('График движения логистической системы')
ax.plot(n_val, x_val, label='f(x)')
ax.grid(which = 'both')
plt.tick_params(axis='both', which='major')
plt.xlabel('n')
plt.ylabel('x')

plt.show()


    
#-------------------------------------ЛАМЕРЕЙ------------------------------------------
xmin = 0
xmax = 1
dx = 0.01

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)
ylist=a*xlist*(1-xlist)

def ff(x):
        return a*x*(1-x) 

def fl(x):
        return x
x=x0
y=x
Y=[]
X=[]
for i in range(1,N,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y

x1=xlist;
y1=[ff(x) for x in x1]
y2=[fl(x) for x in x1]

fig, ax = plt.subplots()
plt.title('Лестица Ламерея логистической системы')
ax.plot(X,Y,'r')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,ylist,'b',label='f(x) = a*x*(1-x)')
plt.plot(x1,y2,'g',label='f(x) = x')
plt.grid(True)
ax.set_xlim([0,1])
ax.set_ylim([0,1])
plt.legend()
plt.show()
#-------------------------------------Функция f(2)(x)----------------------------------------

def ff2(x):
        return a*(a*x*(1-x))*(1-a*x*(1-x))
    
x1=xlist;
y1=[ff2(x) for x in x1]

fig, ax = plt.subplots()
plt.title('График функции второй итерации логистической системы')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(xlist,y1,'b')
plt.grid(True)
#ax.set_xlim([-10,0])
#ax.set_ylim([-10,0])
plt.show()

# %%
a = 1.4
x0 = 0
N = 100
M = 10
n_val = []
x_val = []

n_val.append(0)
x_val.append(x0)

x = x0

for i in range(1, N+1):
    x = pow(a,x)
    n_val.append(i)
    x_val.append(x)
# Вывод графиков

fig, ax = plt.subplots()
plt.title('График движения показательной системы')
ax.plot(n_val, x_val, label='f(x)')
ax.grid(which = 'both')
plt.tick_params(axis='both', which='major')
plt.xlabel('n')
plt.ylabel('x')

plt.show()

    
#-------------------------------------ЛАМЕРЕЙ------------------------------------------
xmin = -1
xmax = 5
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)
ylist=pow(a,xlist)

def ff(x):
        return pow(a,x)

def fl(x):
        return x
x=x0
y=x
Y=[]
X=[]
for i in range(1,N,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y

x1=xlist;
y1=[ff(x) for x in x1]
y2=[fl(x) for x in x1]

fig, ax = plt.subplots()
plt.title('Лестица Ламерея показательной системы')
ax.plot(X,Y,'r')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,ylist,'b',label='f(x) = a^x')
plt.plot(x1,y2,'g',label='f(x) = x')
plt.grid(True)
#ax.set_xlim([0,1])
#ax.set_ylim([0,1])
plt.legend()
plt.show()
#-------------------------------------Функция f(2)(x)----------------------------------------

def ff2(x):
        step = pow(a,x)
        return pow(a,step)
    
x1=xlist;
y1=[ff2(x) for x in x1]

fig, ax = plt.subplots()
plt.title('График функции второй итерации показательной системы')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(xlist,y1,'b')
plt.grid(True)
#ax.set_xlim([-10,0])
#ax.set_ylim([-10,0])
plt.show()

# %%
a = 2
b = 3
x0 = 0
N = 50
M = 10
n_val = []
x_val = []

n_val.append(0)
x_val.append(x0)

x = x0

for i in range(1, N+1):
    x = abs(a*x+b)
    n_val.append(i)
    x_val.append(x)
# Вывод графиков

fig, ax = plt.subplots()
plt.title('График движения |ax+b|')
ax.plot(n_val, x_val, label='f(x)')
ax.grid(which = 'both')
plt.tick_params(axis='both', which='major')
plt.xlabel('n')
plt.ylabel('x')

plt.show()

    
#-------------------------------------ЛАМЕРЕЙ------------------------------------------
xmin = -10
xmax = 10
dx = 0.01

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)
ylist= abs(a*xlist+b)

def ff(x):
        return  abs(a*x+b)

def fl(x):
        return x
x=x0
y=x
Y=[]
X=[]
for i in range(1,5,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y

x1=xlist;
y1=[ff(x) for x in x1]
y2=[fl(x) for x in x1]


fig, ax = plt.subplots()
plt.title('Лестица Ламерея |ax+b|')
ax.plot(X,Y,'r')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,ylist,'b',label='f(x) = |ax+b|')
plt.plot(x1,y2,'g',label='f(x) = x')
plt.grid(True)
ax.set_xlim([-10,10])
ax.set_ylim([-1,20])
plt.legend()
plt.show()
#-------------------------------------Функция f(2)(x)----------------------------------------

def ff2(x):
        return abs(a*abs(a*x+b)+b)
    
x1=xlist;
y1=[ff2(x) for x in x1]

fig, ax = plt.subplots()
plt.title('График функции второй итерации|ax+b|')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(xlist,y1,'b')
plt.grid(True)

plt.show()

# %%
a = 3
x0 = 3/4
N = 10
n_val = []
x_val = []

n_val.append(0)
x_val.append(x0)

x = x0

for i in range(1, N+1):
    x = a*x-int(a*x)
    n_val.append(i)
    x_val.append(x)
# Вывод графиков

fig, ax = plt.subplots()
plt.title('График движения f(x)={ax}')
ax.plot(n_val, x_val, label='f(x)')
ax.grid(which = 'both')
plt.tick_params(axis='both', which='major')
plt.xlabel('n')
plt.ylabel('x')

plt.show()

    
#-------------------------------------ЛАМЕРЕЙ------------------------------------------
xmin = -1
xmax = 5
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)

def ff(x):
        return a*x-int(a*x)

def fl(x):
        return x
x=x0
y=x
Y=[]
X=[]
for i in range(1,N,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y

x1=xlist;
y1=[ff(x) for x in x1]
y2=[fl(x) for x in x1]
        
fig, ax = plt.subplots()
plt.title('Лестица Ламерея f(x)={ax}')
ax.plot(X,Y,'r')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,y1,'b',label='f(x) = {ax}')
plt.plot(x1,y2,'g',label='f(x) = x')
plt.grid(True)
ax.set_xlim([0,1])
ax.set_ylim([0,1])
plt.legend()
plt.show()
#-------------------------------------Функция f(2)(x)----------------------------------------

def ff2(x):
        return a*a*x-int(a*a*x)
    
x1=xlist;
y1=[ff2(x) for x in x1]

fig, ax = plt.subplots()
plt.title('График функции второй итерации{ax}')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(xlist,y1,'b')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

a = 4
m =16
b = 6
x0 = 0
N=100

n_val = []
x_val = []

n_val.append(0)
x_val.append(x0)

x = x0

for i in range(1, N+1):
    x = (a*x + b) mod m 
    n_val.append(i)
    x_val.append(x)
# Вывод графиков

fig, ax = plt.subplots()
plt.title('График движения линейной системы')
ax.plot(n_val, x_val, label='f(x)')
ax.grid(which = 'both')
plt.tick_params(axis='both', which='major')
plt.xlabel('n')
plt.ylabel('x')

plt.show()

print("Числовые значения последних "+str(M)+" точек:\n")
for i in range(0, M):
    print(str(n_val[-(M-i)])+"\t"+str(round(x_val[-(M-i)], 4)))
    
#-------------------------------------ЛАМЕРЕЙ------------------------------------------
xmin = -2
xmax = 2
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4) 

ylist = a*xlist + b

def ff(x):
        return a*x + b

def fl(x):
        return x
x=0.25
y=0
Y=[]
X=[]
for i in range(1,N,1):
        X.append(x)
        Y.append(y)
        y=ff(x)
        X.append(x)
        Y.append(y)
        x=y

x1=xlist;
y1=[ff(x) for x in x1]
y2=[fl(x) for x in x1]

fig, ax = plt.subplots()
plt.title('Лестица Ламерея линейной системы')
ax.plot(X,Y,'r')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,y1,'b',label='f(x) = a*x + b')
plt.plot(x1,y2,'g',label='f(x) = x')
plt.grid(True)
#ax.set_xlim([-10,0])
#ax.set_ylim([-10,0])
plt.legend()
plt.show()
#-------------------------------------Функция f(2)(x)----------------------------------------

def ff2(x):
        return a*a*x + b*(a+1)

x1=xlist;
y1=[ff2(x) for x in x1]

fig, ax = plt.subplots()
plt.title('График функции второй итерации линейной системы')

plt.xlabel('\nX')
plt.ylabel('f(X)')
plt.plot(x1,y1,'b')
plt.grid(True)
#ax.set_xlim([-10,0])
#ax.set_ylim([-10,0])
plt.show()
# Out:
# 0.6000000000000001
